# %% [markdown]
# <a href="https://colab.research.google.com/github/sundaybest3/txtanalysis/blob/refineddata/refining_data_for_wordcount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
from google.colab import files

# =========================
# 1. GitHub CSV 불러오기
# =========================
github_url = "https://raw.githubusercontent.com/sundaybest3/txtanalysis/refs/heads/rawdata/sbcase_56.csv"
csv_url = github_url.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/")

df = pd.read_csv(csv_url)

print(df.columns.tolist())  # 열 이름 확인

# =========================
# 2. 정제 함수
# =========================


def clean_sbcsae_for_wordcount(text):
    if pd.isna(text):
        return text

    text = str(text)

    # --------------------------------
    # A. 단어 내부 기호 먼저 제거 (붙이기)
    # --------------------------------

    text = re.sub(r':+', '', text)      # A:nd → And
    text = re.sub(r'ʔ', '', text)
    text = re.sub(r'%', '', text)

    # --------------------------------
    # B. SBCSAE annotation 제거 (공백 유지)
    # --------------------------------

    text = re.sub(r'&\{[^}]*\}', ' ', text)
    text = re.sub(r'&\}[^ ]*', ' ', text)

    text = re.sub(r'&=\S+', ' ', text)
    text = re.sub(r'=\S+', ' ', text)

    text = re.sub(r'\(\.{1,}\)', ' ', text)
    text = re.sub(r'\+\S*', ' ', text)

    text = re.sub(r'\bX+\b', ' ', text)
    text = re.sub(r'\b\d+\b', ' ', text)

    # overlap markers
    text = re.sub(r'[⌈⌉⌊⌋]', '', text)

    # --------------------------------
    # C. 일반 문장부호 제거 (붙이기)
    # --------------------------------

    text = re.sub(r"[.,!?;:\"()\[\]{}<>]", '', text)

    # --------------------------------
    # D. 영어 단어/공백/' 만 남기기
    # --------------------------------

    text = re.sub(r"[^A-Za-z'\s]", ' ', text)

    # --------------------------------
    # E. 공백 정리
    # --------------------------------

    text = re.sub(r'\s+', ' ', text).strip()

    return text

    # =========================
# 3. script 열에 덮어쓰기
# =========================
df["script"] = df["script"].apply(clean_sbcsae_for_wordcount)

# =========================
# 4. 결과 일부 확인
# =========================
print(df["script"].head(20))

# =========================
# 5. 저장
# =========================
output_file = "cleaned_sbcase_56.csv"
df.to_csv(output_file, index=False, encoding="utf-8-sig")

files.download(output_file)
# Out:
# ['speaker', 'script', 'position1', 'function1', 'position2', 'function2', 'match', 'agreement']
# 0                          l Do you smell the dog on me
# 1                                                  Yeah
# 2                                                  Okay
# 3                                              down boy
# 4                                              Down boy
# 5                                                Mm kay
# 6                                  Jamie wrote this out
# 7                               in a hurry this morning
# 8                                                  Yeah
# 9                          she said she thought she had
# 10                       gotten a brand inspection done
# 11                            since she got to Colorado
# 12    But then she said she didn't know where it was...
# 13                        that's what he wanted to know
# 14                               I've never heard of it
# ...
